# %% [markdown]
# # Python Crash Course - Chapter 5: If Statements
#
# This notebook contains exercises from Chapter 5 of Python Crash Course by Eric Matthes. Each exercise focuses on working with conditional statements and boolean logic.
#
# ## Learning Objectives:
# - Write conditional tests using comparison operators
# - Combine tests using `and` and `or`
# - Use if, elif, and else statements
# - Test for values and membership in lists
# - Handle empty lists and user input validation
# - Apply conditional logic to real-world scenarios
#
# ---
#
# ## 5-1 Conditional Tests

# %%
# Exercise 5-1: Conditional Tests
# Write a series of conditional tests. Print a statement describing each test and your prediction
# for the results of each test. Your code should look something like this:
# car = 'subaru'
# print("Is car == 'subaru'? I predict True.")
# print(car == 'subaru')
# print("\nIs car == 'audi'? I predict False.")
# print(car == 'audi')
# • Look closely at your results, and make sure you understand why each line evaluates to True or False.
# • Create at least 10 tests. Have at least 5 tests evaluate to True and another 5 tests evaluate to False.

# Set up variables for testing
car = 'subaru'
age = 25
name = 'Alice'
numbers = [1, 2, 3, 4, 5]

print("Conditional Tests:")
print("=" * 40)

# Test 1 - should be True
print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')

# Test 2 - should be False  
print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')

# Add 8 more tests (3 more True, 5 more False)
# Tests for True:

# Tests for False:

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-2 More Conditional Tests

# %%
# Exercise 5-2: More Conditional Tests
# You don't have to limit the number of tests you create to 10. If you want to try more comparisons,
# write more tests and add them to conditional_tests.py. Have at least one True and one False result
# for each of the following:
# • Tests for equality and inequality with strings
# • Tests using the lower() function
# • Numerical tests involving equality, inequality, greater than and less than,
#   greater than or equal to, and less than or equal to
# • Tests using the and keyword and the or keyword
# • Test whether an item is in a list
# • Test whether an item is not in a list

print("More Conditional Tests:")
print("=" * 50)

# Set up test variables
name = 'Alice'
number = 15
fruits = ['apple', 'banana', 'cherry']

# String equality and inequality tests
print("\n--- String Tests ---")
print(f"name = '{name}'")
print(f"name == 'Alice': {name == 'Alice'}")
print(f"name == 'Bob': {name == 'Bob'}")
print(f"name != 'Bob': {name != 'Bob'}")
print(f"name != 'Alice': {name != 'Alice'}")

# Tests using lower() function
print("\n--- Lower Case Tests ---")
# Add tests here

# Numerical tests
print("\n--- Numerical Tests ---")
print(f"number = {number}")
# Add equality, inequality, greater than, less than tests

# Tests using 'and' and 'or'
print("\n--- Logical Operator Tests ---")
# Add and/or tests

# Tests for membership in lists
print("\n--- List Membership Tests ---")
print(f"fruits = {fruits}")
# Add 'in' and 'not in' tests

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-3 Alien Colors #1

# %%
# Exercise 5-3: Alien Colors #1
# Imagine an alien was just shot down in a game. Create a variable called alien_color
# and assign it a value of 'green', 'yellow', or 'red'.
# • Write an if statement to test whether the alien's color is green.
# If it is, print a message that the player just earned 5 points.
# • Write one version of this program that passes the if test and another that fails.
# (The output of one version should be the message, and the output of the other version should be nothing.)

print("Alien Colors #1")
print("=" * 20)

# Version 1: Test passes (alien is green)
print("Version 1 - Green alien:")
alien_color = 'green'

# Version 2: Test fails (alien is not green)
print("\nVersion 2 - Red alien:")
alien_color = 'red'

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-4 Alien Colors #2

# %%
# Exercise 5-4: Alien Colors #2
# Choose a color for an alien as you did in Exercise 5-3, and write an if-else chain.
# • If the alien's color is green, print a statement that the player just earned 5 points for shooting the alien.
# • If the alien's color isn't green, print a statement that the player just earned 10 points.
# • Write one version of this program that runs the if block and another that runs the else block.

print("Alien Colors #2")
print("=" * 20)

# Version 1: if block runs (alien is green)
print("Version 1 - Green alien:")
alien_color = 'green'

# Version 2: else block runs (alien is not green)
print("\nVersion 2 - Yellow alien:")
alien_color = 'yellow'

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-5 Alien Colors #3

# %%
# Exercise 5-5: Alien Colors #3
# Turn your if-else chain from Exercise 5-4 into an if-elif-else chain.
# • If the alien is green, print a message that the player earned 5 points.
# • If the alien is yellow, print a message that the player earned 10 points.
# • If the alien is red, print a message that the player earned 15 points.
# • Write three versions of this program, making sure each message is printed for the appropriate color alien.

print("Alien Colors #3")
print("=" * 20)

# Version 1: Green alien (5 points)
print("Version 1 - Green alien:")
alien_color = 'green'

# Version 2: Yellow alien (10 points)
print("\nVersion 2 - Yellow alien:")
alien_color = 'yellow'

# Version 3: Red alien (15 points)
print("\nVersion 3 - Red alien:")
alien_color = 'red'

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-6 Stages of Life

# %%
# Exercise 5-6: Stages of Life
# Write an if-elif-else chain that determines a person's stage of life. Set a value for the variable age, and then:
# • If the person is less than 2 years old, print a message that the person is a baby.
# • If the person is at least 2 years old but less than 4, print a message that the person is a toddler.
# • If the person is at least 4 years old but less than 13, print a message that the person is a kid.
# • If the person is at least 13 years old but less than 20, print a message that the person is a teenager.
# • If the person is at least 20 years old but less than 65, print a message that the person is an adult.
# • If the person is age 65 or older, print a message that the person is an elder.

# Test different ages
ages_to_test = [1, 3, 7, 15, 25, 70]

print("Stages of Life")
print("=" * 20)

for age in ages_to_test:
    print(f"\nAge {age}:", end=" ")
    
    # Write if-elif-else chain here
    
# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-7 Favorite Fruit

# %%
# Exercise 5-7: Favorite Fruit
# Make a list of your three favorite fruits and call it favorite_fruits.
# Write a series of independent if statements that check for certain fruits in your list.
# • Make a list of three fruits and call it fruits_to_check.
# • Write an if statement for each fruit in fruits_to_check. In each if statement,
#   check whether each fruit is in your list of favorite fruits.
#   If the fruit is in your list, print a message like "You really like bananas!"

# Create list of favorite fruits
favorite_fruits = ['', '', '']

# Create list of fruits to check (mix of favorites and non-favorites)
fruits_to_check = ['', '', '']

print("Favorite Fruit Checker")
print("=" * 25)
print(f"My favorite fruits: {favorite_fruits}")
print(f"Checking for: {fruits_to_check}")
print()

# Write independent if statements for each fruit to check

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-8 Hello Admin

# %%
# Exercise 5-8: Hello Admin
# Make a list of five or more usernames, including the name 'admin'.
# Imagine you are writing code that will print a greeting to each user after they log in.
# • Loop through the list, and print a greeting to each user.
# • If the username is 'admin', print a special greeting, such as "Hello admin, would you like to see a status report?"
# • Otherwise, print a generic greeting, such as "Hello Jaden, thank you for logging in again."

# Create list of usernames including 'admin'
usernames = ['admin', '', '', '', '']

print("User Login Greetings")
print("=" * 25)

# Loop through usernames and print appropriate greeting

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-9 No Users

# %%
# Exercise 5-9: No Users
# Add an if test to hello_admin.py to make sure the list of users is not empty.
# • If the list is empty, print the message "We need to find some users!"
# • Remove all of the usernames from your list, and make sure the correct message is printed.

print("No Users Test")
print("=" * 20)

# Test 1: List with users
print("Test 1 - List with users:")
usernames = ['admin', 'alice', 'bob', 'charlie', 'diana']

# Test 2: Empty list
print("\nTest 2 - Empty list:")
usernames = []

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-10 Checking Usernames

# %%
# Exercise 5-10: Checking Usernames
# Do the following to create a program that simulates how websites ensure that everyone has a unique username.
# • Make a list of five or more usernames called current_users.
# • Make another list of five usernames called new_users. Make sure one or two of the new usernames
#   are also in the current_users list.
# • Loop through the new_users list to see if each new username has already been used.
#   If it has, print a message that the person will need to enter a new username.
#   If a username has not been used, print a message saying that the username is available.
# • Make sure your comparison is case insensitive. If 'John' has been used, 'JOHN' should not be accepted.

# Create list of current users
current_users = ['admin', 'alice', 'bob', 'charlie', 'diana']

# Create list of new users (include some duplicates with different cases)
new_users = ['eve', 'ALICE', 'frank', 'Bob', 'grace']

print("Username Availability Checker")
print("=" * 35)
print(f"Current users: {current_users}")
print(f"New users to check: {new_users}")
print()

# Create lowercase version of current_users for case-insensitive comparison
current_users_lower = [user.lower() for user in current_users]

# Check each new username

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ## 5-11 Ordinal Numbers

# %%
# Exercise 5-11: Ordinal Numbers
# Ordinal numbers indicate their position in a list, such as 1st or 2nd.
# Most ordinal numbers end in th, except 1, 2, and 3.
# • Store the numbers 1 through 9 in a list.
# • Loop through the list.
# • Use an if-elif-else chain inside the loop to print the proper ordinal ending for each number.
#   Your output should read "1st 2nd 3rd 4th 5th 6th 7th 8th 9th", and each result should be on a separate line.

# Create list of numbers 1 through 9
numbers = list(range(1, 10))

print("Ordinal Numbers")
print("=" * 20)

# Loop through numbers and add appropriate ordinal ending
for number in numbers:
    # Use if-elif-else to determine the correct ending
    
    pass  # Remove this line when you add your code

# Here I will write the code and corresponding comments to complete the training tasks

# %% [markdown]
# ---
#
# ## Summary
#
# Congratulations! You've completed all the exercises for Chapter 5 on If Statements. You should now be comfortable with:
#
# - Writing conditional tests using comparison operators
# - Using logical operators (`and`, `or`, `not`)
# - Creating if, elif, and else statements
# - Testing for membership in lists (`in`, `not in`)
# - Handling different data types in conditions
# - Working with empty lists and user validation
#
# **Key Concepts Practiced:**
# - Comparison operators: `==`, `!=`, `<`, `>`, `<=`, `>=`
# - Logical operators: `and`, `or`, `not`
# - Conditional statement structure: `if`, `elif`, `else`
# - List membership testing: `item in list`, `item not in list`
# - Case-insensitive string comparisons using `.lower()`
# - Boolean evaluation and truthiness
#
# **Next Steps:**
# - Review any exercises you found challenging
# - Practice writing more complex conditional logic
# - Combine conditionals with loops for powerful programs
# - Move on to Chapter 6: Dictionaries
#
# ---
#
# *Note: Understanding conditional logic is fundamental to programming. These patterns will appear in almost every program you write!*
